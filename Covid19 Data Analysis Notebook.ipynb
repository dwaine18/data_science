# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
covid19_data = pd.read_csv("covid19_Confirmed_dataset.csv")
covid19_data.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
covid19_data.shape
# Out:
# (266, 104)

# %%
# remove Lat and Long as they are not needed for this project

covid19_data
# Out:
#     Province/State         Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0              NaN            Afghanistan        0        0        0        0
# 1              NaN                Albania        0        0        0        0
# 2              NaN                Algeria        0        0        0        0
# 3              NaN                Andorra        0        0        0        0
# 4              NaN                 Angola        0        0        0        0
# ..             ...                    ...      ...      ...      ...      ...
# 261            NaN         Western Sahara        0        0        0        0
# 262            NaN  Sao Tome and Principe        0        0        0        0
# 263            NaN                  Yemen        0        0        0        0
# 264            NaN                Comoros        0        0        0        0
# 265            NaN             Tajikistan        0        0        0        0
#
# ...

# %%
covid19_data.shape
# Out:
# (266, 102)

# %%
df = covid19_data

# %%
df.shape
# Out:
# (266, 102)

# %%
df.head()
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
df = df.groupby('Country/Region').sum()

# %%
df
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza        0        0        0        0        0        0
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
# ...

# %%
df.shape
# Out:
# (187, 100)

# %%
#plot number of cases for Jamaica
df.loc['Jamaica'].plot()
# Out:
# <AxesSubplot:>

# %%
#plot the number of cases for the United States of America

df.loc['US'].plot()
# Out:
# <AxesSubplot:>

# %%
clist = df.index

# %%
for country in clist:
    if country[0] == 'U':
        print(country)
# Out:
# US
# Uganda
# Ukraine
# United Arab Emirates
# United Kingdom
# Uruguay
# Uzbekistan

# %%
# Plot both countries on the same plot 
df.loc['Jamaica'].plot()
df.loc['US'].plot()
plt.legend()

# %%
# check number of confirmed cases in china over the first 3 days of the crisis

df.loc['China'][:3].plot()
# Out:
# <AxesSubplot:>

# %%
#let's find the first derivative of daily infection rates in China to find the maximum number.

df.loc['China'].diff().plot()
# Out:
# <AxesSubplot:>

# %%
df.loc['China'].diff().max()
# Out:
# 15136.0
